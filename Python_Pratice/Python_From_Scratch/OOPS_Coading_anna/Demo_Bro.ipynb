# %%
def summa(a):
    print('Before Executing')
    a()
    print("After Executing")
@summa    
def robo():
    print('summa')
# Out:
# Before Executing
# summa
# After Executing

# %%
class aravind:
    def __init__(self, name, aravind):
        self.name = name
        self.aravind = aravind
