# %% [markdown]
# ### Operator is nothing but the thing it will do the action !
#
# like doctor doing a surgery - he is a operator (just for example)
#
# - (+, -, *) all are operator
# - we have 7 operators. .
#
# 1. Arithmetic operator
# 2. assignment operator
# 3. Comparison operator
# 4. Logical operator
# 5. Identity operator
# 6. Membersip operator

# %% [markdown]
# ### Arithmetic operator
#
# * Addition operators

# %%
print(5+6) # - arithmetic operator 
print(5-6)
print(5//6)
print(5/6)
print(5*6) # - exponents its power(**), multiply(*) 
print(5%6) # Modulus - Reminder of dividing
# Out:
# 11
# -1
# 0
# 0.8333333333333334
# 30
# 5

# %% [markdown]
# ### Assignment Operator
#
# * Assigning value to something

# %%
x = 1 # assigning the value ( equals to )
print(x)

x += 8
print(x) # assigning operator
# Out:
# 1
# 9

# %% [markdown]
# ### Comparison Operator
#
# * Compare the value to other
# * **Whenever you are comparing anything you need to put double sign**
#
#
# like ( if else statment )

# %%
# it has > < >= <= 
a = 1
b = 1
if a == b: 
    print('True')
# Out:
# True

# %% [markdown]
# ### Logical Operators
#
# * True False, Boolean are logical operators

# %% [markdown]
# ### Identity operator

# %%
a = 2
b =3 
print( a is b) # is - identity operaotr 

print( a is not b) # is not - identity operoator
# Out:
# False

# %% [markdown]
# ### Membership operator

# %%
a = [1,2,3,4,5]

print(1 not in a)  # not in membership operator 

# in and not in
# Out:
# False

# %%
def findeven(a):
    if a %2==0:
        print('This number is even')
    else:
        print('This Number is not an even')

# %%
findeven(3
# Out:
# This Number is not an even

# %%
from pratice import findeven

# %%
findeven(2)
# Out:
# This number is even
