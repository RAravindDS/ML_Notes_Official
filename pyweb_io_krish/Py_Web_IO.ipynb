# %%
#!pip install pywebio

# %%
from pywebio.input import *
from pywebio.output import *

# %% [markdown]
# # This is for text

# %%
name = input('Enter your name', type = "text")

# %%
name

# %% [markdown]
# # This is for numbers

# %%
age = input('Enter your age', type = FLOAT) # we can use 'NUMBER' also

# %%
age

# %% [markdown]
# # some other types

# %%
# password 
password = input('Type your password', type = PASSWORD)

# Drop down selection 
gift = select('which gift you want', ['keyboard', 'ipad'])


# checkbox 
agree = checkbox('Use Term', options = ['I agree the terms and conditions'])

# Multi-line text input
text = textarea('Text Area', rows =3, placholder = 'Some text')

# File upload
img = file_upload('Select a image', accept = "image/*") 


# choose any one
operation = radio('choose any one', options = ['+', '-', '/', '*'])

# %%
text
# Out:
# 'arajfjdjfkljlkdjfkljlkdjflkjds'

# %%
def check(p):
    if p > 60: 
        print('Too old')
    else: 
        print('Too young')
        
age = input('How old are you', type = FLOAT, validate = check)

# %% [markdown]
# # we can give env also

# %%
code = textarea('code edit', code = {'mode': 'python', 'theme': 'darcula'}, 
               value = 'import something\n# Write you own code')
